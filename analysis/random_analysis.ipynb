# %%
from pandas import DataFrame
import seaborn as sns
from data_analysis import make_cat_plots_for_adversaries, read_random_vs_adversary_data

# %%
random_df: DataFrame = read_random_vs_adversary_data()
print(random_df.columns)
random_df.describe()
# Out:
# Index(['score', 'turns_taken', 'execution_time', 'largest_tile', 'adversary',
#        'monte_carlo_depth', 'rollout', 'depth'],
#       dtype='str')
#              score  turns_taken  execution_time  largest_tile  \
# count  2000.000000  2000.000000     2000.000000   2000.000000
# mean   1028.588000   216.311000       22.805213     92.420000
# std    1299.225079   170.227889       33.673903    117.644174
# min      80.000000    54.000000        0.005856      8.000000
# 25%     316.000000   116.000000        1.204774     32.000000
# 50%     440.000000   142.000000        8.544271     32.000000
# 75%     821.000000   208.000000       27.982498     64.000000
# max    7232.000000  1000.000000      192.272652    512.000000
#
#        monte_carlo_depth  rollout   depth
# count              500.0    500.0  2000.0
# mean                12.0     20.0     5.0
# std                  0.0      0.0     0.0
# min                 12.0     20.0     5.0
# 25%                 12.0     20.0     5.0
# 50%                 12.0     20.0     5.0
# 75%                 12.0     20.0     5.0
# max                 12.0     20.0     5.0

# %%
# Compare average scores for each adversary
make_cat_plots_for_adversaries(
    data=random_df,
    x="adversary",
    title="Statistics for Random vs Adversaries",
    linestyles="",
    ci=95,
)

make_cat_plots_for_adversaries(
    data=random_df[~(random_df["adversary"] == "random")],
    x="adversary",
    title="Statistics for Random vs Adversaries",
    linestyles="",
    ci=95,
)
